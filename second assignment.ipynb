# %% [markdown]
# <a href="https://colab.research.google.com/github/luckymowzey/AI_Modeling_MUK/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import *
sqrt(48)
pi
import numpy as np
a = np.array([1,4,5,6], int)
print(a)
b = np.array([[1,4,5,6],[7,8,9,10]], int)
print(b)
b.shape
b.reshape((4,2))
b.transpose()
x = np.array([1,2,3], int)
y = np.array([4,5,6], int)
z = x + y
z
x = np.array([1,2,3], int)
for i in x:
  print(i)
x.sum()
x.prod()
import pandas as pd
a = [1,2,3,4]
print(a)
dataframe = pd.Series(a)
print(dataframe)
dataframe = pd.Series(a, index=['w','x', 'y', 'z'])
print(dataframe)
data = {
    "Calories" : [429,380, 390],
    "Duration" : [50,40,30]
    }
df = pd.DataFrame(data, index=["Day1", "Day2", "Day3"])
print(df)
print(df.loc["Day2"])
data = {
    "Calories" : [429, 380, 390],
    "Duration" : [50,40,30]
}
df = pd.DataFrame(data)
print(df.loc[1])
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
path = "/content/drive/MyDrive/test_standard_bank.csv"
df = pd.read_csv(path)
df.describe
df.head(20)
df.tail()
df.info()
import numpy as np
from matplotlib import pyplot as plt
data = {
    "Day1" : 420, "Day2" : 200, "Day3" : 520
    }
print(data)
days = list(data.keys())
calories = list(data.values())
print(days)
print(calories)
fig = plt.figure(figsize= (10, 5))
plt.bar(days, calories, color="blue", width=0.5)
plt.xlabel("Days")
plt.ylabel("Calories")
plt.title("A graph of calories against Days")
plt.show()
import seaborn as sns
tips = sns.load_dataset("tips")
sns.displot(tips, x="size")
# Out:
# [1 4 5 6]
# [[ 1  4  5  6]
#  [ 7  8  9 10]]
# 1
# 2
# 3
# [1, 2, 3, 4]
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# w    1
# x    2
# y    3
# z    4
# dtype: int64
#       Calories  Duration
# Day1       429        50
# Day2       380        40
# Day3       390        30
# Calories    380
# Duration     40
# Name: Day2, dtype: int64
# Calories    380
# Duration     40
# Name: 1, dtype: int64
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
# ...
